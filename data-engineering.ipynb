# %% [markdown]
# Contents
# 1. Importing libraries
# 2. Importing data
# 3. Checking and cleaning data

# %% [markdown]
# 1. Importing libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# 2. Importing data

# %%
import_df = pd.read_excel('Raw_Data.xlsx',sheet_name='Main',header=[0])

#Transpose 
import_df = import_df.T

#Reset index 
import_df = import_df.reset_index()

#Set the first column to 'State'
import_df.columns = ['State']+list(import_df.iloc[0,1:])

#Drop the first row 
import_df = import_df.iloc[1:]

import_df.drop(['Overview'],axis=1)

import_df.head()
# Out:
#         State Overview Total Population 2021
# 1     Alabama      NaN             5039877.0  \
# 2      Alaska      NaN              732673.0
# 3     Arizona      NaN             7276316.0
# 4    Arkansas      NaN             3025891.0
# 5  California      NaN            39237836.0
#
#   Population Growth or Decline 2010 to 2021 Households 2020
# 1                                     0.054       1888504.0  \
# 2                                     0.032        255173.0
# 3                                     0.138       2643430.0
# 4                                     0.038       1170544.0
# 5                                     0.053      13103114.0
#
#   Labor Force (persons) Ann. Avg. 2021 Unemployment Rate Ann. Avg. 2021
# 1                                  NaN                              NaN  \
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
#
#   Per Capita Personal Income 2021 Median Household Income 2020
# 1                         49769.0                      53958.0  \
# 2                         65813.0                      79961.0
# 3                         55487.0                      64652.0
# 4                         50625.0                      51146.0
# 5                         76614.0                      83001.0
#
#   Poverty Rate 2020  ... Unemployment Rate 10-Year Pct. Chg
# 1              14.9  ...                                NaN  \
# 2               9.6  ...                                NaN
# 3              12.8  ...                                NaN
# 4              15.2  ...                                NaN
# 5              11.5  ...                                NaN
#
#   Educational Attainment in 2020 Total Population 25 and Older
# 1                            NaN                     3344006.0  \
# 2                            NaN                      483436.0
# 3                            NaN                     4846056.0
# 4                            NaN                     2026722.0
# 5                            NaN                    26665143.0
#
#   Less than 9th Grade 9th to 12th, No Diploma
# 1            133650.0                305297.0  \
# 2             11513.0                 21663.0
# 3            248570.0                339349.0
# 4             95403.0                164957.0
# 5           2367996.0               1918542.0
#
#   High School Graduate (includes equiv.) Some College, No Degree
# 1                              1014342.0                721609.0  \
# 2                               137486.0                125645.0
# 3                              1151988.0               1208298.0
# 4                               686812.0                445268.0
# 5                              5431385.0               5566520.0
#
#   Associate Degree Bachelor's Degree
# 1         292064.0          546674.0  \
# 2          42162.0           90161.0
# 3         429153.0          911228.0
# 4         151587.0          308648.0
# 5        2123827.0         5764827.0
#
#   Graduate, Professional or Doctorate Degree
# 1                                   330370.0
# 2                                    54806.0
# 3                                   557470.0
# 4                                   174047.0
# 5                                  3492046.0
#
# [5 rows x 130 columns]

# %% [markdown]
# 2.1 Identify all the columns with NaN values and reconcile

# %%
nan_columns = import_df.isna().any()
nan_columns = nan_columns[nan_columns].index.tolist()
# Out:
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN
# 50    NaN
# Name: Overview, dtype: object
